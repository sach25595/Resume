# %%
# Reading the cleaned numeric car prices data
import pandas as pd
import numpy as np
import keras

# To remove the scientific notation from numpy arrays
np.set_printoptions(suppress=True)

CarPricesDataNumeric=pd.read_excel('Golbal_combined2.xlsx')
CarPricesDataNumeric.head()
import matplotlib.pyplot as plt

# %%
# Separate Target Variable and Predictor Variables
TargetVariable=['Confirmed']
Predictors=['Date']
X=CarPricesDataNumeric[Predictors].values
y=CarPricesDataNumeric[TargetVariable].values
### Sandardization of data ###
from sklearn.preprocessing import StandardScaler
PredictorScaler=StandardScaler()
TargetVarScaler=StandardScaler()
# Storing the fit object for later reference
PredictorScalerFit=PredictorScaler.fit(X)
TargetVarScalerFit=TargetVarScaler.fit(y)
# Generating the standardized values of X and y
X=PredictorScalerFit.transform(X)
y=TargetVarScalerFit.transform(y)
# Split the data into training and testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Quick sanity check with the shapes of Training and testing datasets
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (350, 1)
# (350, 1)
# (150, 1)
# (150, 1)

# %%
# importing the libraries
from keras.models import Sequential
from keras.layers import Dense

# create ANN model
model = Sequential()

# %%
# Defining the Input layer and FIRST hidden layer, both are same!
model.add(Dense(units=45, input_dim=1, kernel_initializer='normal', activation='relu'))

# Defining the Second layer of the model
# after the first layer we don't have to specify input_dim as keras configure it automatically
model.add(Dense(units=45, kernel_initializer='normal', activation='tanh'))
# The output neuron is a single fully connected node 
# Since we will be predicting a single number
model.add(Dense(1, kernel_initializer='normal'))

# Compiling the model
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Fitting the ANN to the Training set
model.fit(X_train, y_train ,batch_size = 30, epochs = 500, verbose=1)
# Out:
# Epoch 1/500
# 12/12 [==============================] - 1s 3ms/step - loss: 0.9140
# Epoch 2/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8546
# Epoch 3/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7367
# Epoch 4/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5622
# Epoch 5/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4049
# Epoch 6/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3488
# Epoch 7/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3173
# Epoch 8/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3027
# Epoch 9/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2946
# Epoch 10/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2910
# Epoch 11/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2872
# Epoch 12/500
# ...

# %%
# Defining a function to find the best parameters for ANN
def FunctionFindBestParams(X_train, y_train, X_test, y_test):
    
    # Defining the list of hyper parameters to try
    batch_size_list=[20, 30, 40, 50]
    epoch_list  =   [300, 400, 500, 600]
    
    import pandas as pd
    SearchResultsData=pd.DataFrame(columns=['TrialNumber', 'Parameters', 'Accuracy'])
    
    # initializing the trials
    TrialNumber=0
    for batch_size_trial in batch_size_list:
        for epochs_trial in epoch_list:
            TrialNumber+=1
            # create ANN model
            model = Sequential()
            # Defining the first layer of the model
            model.add(Dense(units=5, input_dim=X_train.shape[1], kernel_initializer='normal', activation='relu'))

            # Defining the Second layer of the model
            model.add(Dense(units=5, kernel_initializer='normal', activation='relu'))

            # The output neuron is a single fully connected node 
            # Since we will be predicting a single number
            model.add(Dense(1, kernel_initializer='normal'))

            # Compiling the model
            model.compile(loss='mean_squared_error', optimizer='adam')

            # Fitting the ANN to the Training set
            model.fit(X_train, y_train ,batch_size = batch_size_trial, epochs = epochs_trial, verbose=0)

            MAPE = np.mean(100 * (np.abs(y_test-model.predict(X_test))/y_test))
            
            # printing the results of the current iteration
            print(TrialNumber, 'Parameters:','batch_size:', batch_size_trial,'-', 'epochs:',epochs_trial, 'Accuracy:', 100-MAPE)
            
            SearchResultsData=SearchResultsData.append(pd.DataFrame(data=[[TrialNumber, str(batch_size_trial)+'-'+str(epochs_trial), 100-MAPE]],
                                                                    columns=['TrialNumber', 'Parameters', 'Accuracy'] ))
    return(SearchResultsData)


######################################################
# Calling the function
ResultsData=FunctionFindBestParams(X_train, y_train, X_test, y_test)
# Out:
# 1 Parameters: batch_size: 20 - epochs: 300 Accuracy: 208.23074276841783
# 2 Parameters: batch_size: 20 - epochs: 400 Accuracy: 191.4366342917217
# 3 Parameters: batch_size: 20 - epochs: 500 Accuracy: 241.44384886130993
# 4 Parameters: batch_size: 20 - epochs: 600 Accuracy: 238.92767729663922
# 5 Parameters: batch_size: 30 - epochs: 300 Accuracy: 212.59071955365857
# 6 Parameters: batch_size: 30 - epochs: 400 Accuracy: 289.4150335684144
# 7 Parameters: batch_size: 30 - epochs: 500 Accuracy: 203.52711339640484
# 8 Parameters: batch_size: 30 - epochs: 600 Accuracy: 180.9296942106037
# 9 Parameters: batch_size: 40 - epochs: 300 Accuracy: 204.1134398448015
# 10 Parameters: batch_size: 40 - epochs: 400 Accuracy: 201.2986231100728
# 11 Parameters: batch_size: 40 - epochs: 500 Accuracy: 201.18440579296583
# 12 Parameters: batch_size: 40 - epochs: 600 Accuracy: 192.54201115941467
# 13 Parameters: batch_size: 50 - epochs: 300 Accuracy: 217.25321289081563
# ...

# %%
# %matplotlib inline
ResultsData.plot(x='Parameters', y='Accuracy', figsize=(15,4), kind='line')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# Fitting the ANN to the Training set
model.fit(X_train, y_train ,batch_size = 50, epochs = 300, verbose=0)

# Generating Predictions on testing data
Predictions=model.predict(X_test)

# Scaling the predicted Price data back to original price scale
Predictions=TargetVarScalerFit.inverse_transform(Predictions)

# Scaling the y_test Price data back to original price scale
y_test_orig=TargetVarScalerFit.inverse_transform(y_test)

# Scaling the test data back to original scale
Test_Data=PredictorScalerFit.inverse_transform(X_test)

TestingData=pd.DataFrame(data=Test_Data, columns=Predictors)
TestingData['Confirmed_Cases']=y_test_orig
TestingData['Predicted_Confirmed_Cases']=Predictions
TestingData.head()
# Out:
#       Date  Confirmed_Cases  Predicted_Confirmed_Cases
# 0  44274.0         563241.0              511602.093750
# 1  43986.0         138097.0              134004.765625
# 2  44287.0         710063.0              617252.187500
# 3  44068.0         245509.0              269209.468750
# 4  44017.0         185990.0              199938.531250

# %%
# Computing the absolute percent error
APE=100*(abs(TestingData['Confirmed_Cases']-TestingData['Predicted_Confirmed_Cases'])/TestingData['Confirmed_Cases'])
TestingData['APE']=APE

print('The Accuracy of ANN model is:', 100-np.mean(APE))
TestingData.head(8)
# Out:
# The Accuracy of ANN model is: 85.2206689309472
#       Date  Confirmed_Cases  Predicted_Confirmed_Cases        APE
# 0  44274.0         563241.0              511602.093750   9.168172
# 1  43986.0         138097.0              134004.765625   2.963304
# 2  44287.0         710063.0              617252.187500  13.070786
# 3  44068.0         245509.0              269209.468750   9.653605
# 4  44017.0         185990.0              199938.531250   7.499614
# 5  44307.0         889226.0              780091.375000  12.272991
# 6  44290.0         559330.0              641666.000000  14.720469
# 7  44037.0         249997.0              255486.390625   2.195783
