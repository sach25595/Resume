# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('smokers.xlsx')

# %%
del df['Average of population_density']

# %%
del df['Sum of new_vaccinations']

# %%
df
# Out:
#          country  Deaths       Smokers  diabetes_patients  \
# 0    Afghanistan    7651  0.000000e+00       3.820218e+06
# 1        Albania    3487  8.374603e+05       2.895917e+05
# 2        Algeria    6869  6.937885e+06       3.002699e+06
# 3        Andorra     152  2.583624e+04       6.165114e+03
# 4         Angola    1903  0.000000e+00       1.336984e+06
# ..           ...     ...           ...                ...
# 197    Venezuela    5669  0.000000e+00       1.857210e+06
# 198      Vietnam   41792  2.302059e+07       5.890130e+06
# 199        Yemen    2140  5.610278e+06       1.631249e+06
# 200       Zambia    3961  2.629971e+06       7.454739e+05
# 201     Zimbabwe    5418  2.437386e+06       2.746775e+05
#
#      avg cardiovasc death per year  Population  Confirmed_cases
# 0                    237829.057434    39835428           176751
# 1                      8739.321581     2872934           272804
# 2                    124196.624799    44616626           265496
# ...

# %%
df.corr()
# Out:
#                                  Deaths   Smokers  diabetes_patients  \
# Deaths                         1.000000  0.343439           0.423625
# Smokers                        0.343439  1.000000           0.902229
# diabetes_patients              0.423625  0.902229           1.000000
# avg cardiovasc death per year  0.362983  0.907704           0.981248
# Population                     0.406590  0.878165           0.944288
# Confirmed_cases                0.922714  0.346303           0.438595
#
#                                avg cardiovasc death per year  Population  \
# Deaths                                              0.362983    0.406590
# Smokers                                             0.907704    0.878165
# diabetes_patients                                   0.981248    0.944288
# avg cardiovasc death per year                       1.000000    0.939149
# Population                                          0.939149    1.000000
# ...

# %%
sns.pairplot(df)

# %%
plt.figure(figsize = (12,12))
sns.heatmap(df.corr(),annot = True,cmap="YlGnBu")
plt.savefig('dataplot.png')
